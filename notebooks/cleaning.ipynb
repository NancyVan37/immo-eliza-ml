# %%
import pandas as pd

file_path = r"C:\Users\vande\becode\immo-eliza-ml\cleaned_properties.csv"

# Load CSV into a DataFrame
cleaned_properties = pd.read_csv(file_path)

# %%
#Removing Duplicates
# Remove duplicate rows and update the DataFrame
cleaned_properties = cleaned_properties.drop_duplicates()

# Optional: check how many rows remain
print(f"Number of rows after removing duplicates: {len(cleaned_properties)}")
# Out:
# Number of rows after removing duplicates: 75508
